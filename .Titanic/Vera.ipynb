# %%
# ¿Cuántos pasajeros hay en cada Clase (Pclass)?

#Hay en total 418 pasajeros, de estos hay 107 en la primera clase, hay 93 en la segunda clase y hay 218 en la tercera clase.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 25.0 MB/s  0:00:00m0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 40.2 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#¿Cuál es la edad promedio (Age) de los pasajeros, agrupados por su Sexo?

import pandas as pd

df = pd.read_csv("test.csv")

promedios = df.groupby("Sex")["Age"].mean()

print(promedios)
# Out:
# Sex
# female    30.272362
# male      30.272732
# Name: Age, dtype: float64

# %%
#La edad promedio es la de arriba
