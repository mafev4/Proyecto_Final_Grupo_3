# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', encoding='utf8')

# %%
df["n"] = df["Número de documento"].astype(str).apply(
    lambda x: sum(int(i) for i in x))

# %%
def punto1(n):
    n1=int(n[4]) 
    c105=(n1*105**2)+(2*105)+23
    c100=(n1*100**2)+(2*100)+23
    fc1=(c105-c100)/(105-100)
    return fc1

# %%
df["Punto 1"]=df.apply(punto1, axis=1)
# Out:
# /tmp/ipykernel_18660/1714048167.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   n1=int(n[4])

# %%
def calificación1(n):
    n1=int(n[5])
    n2=int(n[1])
    if n1==n2:
        return 5
    else:
        return 1

# %%
df["Calificación P1"]=df.apply(calificación1, axis=1)
# Out:
# /tmp/ipykernel_18660/3851657706.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   n1=int(n[5])
# /tmp/ipykernel_18660/3851657706.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   n2=int(n[1])

# %%
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# ...

# %%
df.to_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', index=False)

# %%
def cf(n):
    nota1=int(n[6]) 
    nota2=int(n[8]) 
    nota3=int(n[10])
    notafinal=(nota1+nota2+nota3)/3 
    return round(notafinal, 2)

# %%
df["Calificación Final"]=df.apply(cf, axis=1)
# Out:
# /tmp/ipykernel_18660/3679134581.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   nota1=int(n[6])
# /tmp/ipykernel_18660/3679134581.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   nota2=int(n[8])
# /tmp/ipykernel_18660/3679134581.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   nota3=int(n[10])

# %%
df.to_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', index=False)

# %%
df = df.rename(columns={"Calificación P1": "CP1"})
df = df.rename(columns={"Calificación Final": "NF"})

# %%
df
# Out:
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# ...

# %%
df.to_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', index=False)

# %%
def promedio(na, nc):
    try:
        df = pd.read_csv(na)
        
        if nc not in df.columns:
            return "No existe la columna"

        return df[nc].mean()

    except Exception as e:
        return f"Error al procesar la columna"

# %%
promedio('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', 'CP1')
# Out:
# np.float64(3.888888888888889)

# %%
df.to_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', index=False)

# %%
def percentil(na, nc):
    try:
        df = pd.read_csv(na)

        if nc not in df.columns:
            return "Error al procesar la columna"

        p25 = df[nc].quantile(0.25)
        p50 = df[nc].quantile(0.50)
        p75 = df[nc].quantile(0.75)

        return p25, p50, p75

    except Exception as e:
        return f"Error al procesar la columna"

# %%
percentil("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv", "CP1")
# Out:
# (np.float64(2.0), np.float64(5.0), np.float64(5.0))

# %%
df.to_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', index=False)

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

prom_cp1 = df.filter(regex="CP1").iloc[:, 0].mean()
prom_nf  = df.filter(regex="NF").iloc[:, 0].mean()
prom_cp2 = df["CP2"].mean()
prom_cp3 = df["CP3"].mean()
plt.figure(figsize=(6,4))
plt.title("Promedios")
plt.bar(
    ["CP1", "CP2", "CP3", "NF"],
    [prom_cp1, prom_cp2, prom_cp3, prom_nf]
)

plt.ylabel("Promedio")
plt.xlabel("Calificaciones")
plt.show()

# %%
df.to_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', index=False)

# %%
nf = df.filter(regex="NF").iloc[:, 0]

percentiles = list(range(10, 100, 10))

valores = np.percentile(nf, percentiles)

plt.figure(figsize=(8,5))
plt.title("Percentiles")

plt.bar([str(p) for p in percentiles], valores)

plt.xlabel("Percentil")
plt.ylabel("Valor en NF")
plt.show()

# %%
df.to_csv('Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv', index=False)
